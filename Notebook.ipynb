# %%
import matplotlib.pyplot as plt
from plot_drawer import draw_plots

json_path = '/Users/Openiuk/DocuSketch_test/deviation.json'

plot_paths = draw_plots(json_path)

for path in plot_paths:
    img = plt.imread(path)
    plt.imshow(img)
    plt.show()
